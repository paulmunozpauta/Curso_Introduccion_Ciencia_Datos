# %% [markdown]
# <p align="center">
#   <img src="https://raw.githubusercontent.com/paulmunozpauta/Curso_Introduccion_Ciencia_Datos/main/Static/Imgs/UdeC_color_horizontal.jpg" width="500">
# </p>
# <p align="center"><b style="font-size:28px;">Facultad de Ingeniería Agrícola</b></p>
# <p align="center"><b style="font-size:28px;">Introducción a la Ciencia de Datos</b></p>
# <hr>
# <p align="center"><b style="font-size:28px;">Contacto</b></p>
# <p align="center">
#   paulmunoz@udec.cl<br>
#   https://paulmunoz.com
# </p>

# %% [markdown]
# ##  <center> SESIÓN 1: Directorios, rutas y carpetas

# %% [markdown]
# El objetivo de esta sesión es organizar los archivos/carpetas de un estudio/proyecto.
#
# a. Para leer datos
#
# b. Para exportar resultados

# %% [markdown]
# Esto se puede hacer de forma sistemática a través de un lenguaje de programación

# %% [markdown]
# ![python.png](Imágenes/python.png)

# %% [markdown]
# ![r.jpeg](Imágenes/r.jpeg)

# %% [markdown]
# ![matlab.jpg](Imágenes/matlab.jpeg)

# %% [markdown]
# Instalación de Anaconda para Python
# ![anaconda.png](Imágenes/anaconda.png)

# %% [markdown]
# Descarga del software para Windows, MacOS y Linux: https://www.anaconda.com/products/distribution

# %% [markdown]
# Creación de un Environment para este curso/proyecto

# %% [markdown]
# ![env1.png](Imágenes/env1.png)

# %% [markdown]
# Creamos un nuevo environment con el nombre **DataAnalytics** con Python **versión 3.7**

# %% [markdown]
# ![env2.png](Imágenes/env2.png)

# %% [markdown]
# ## 0. Cargar librerías para esta sesión

# %%
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Directorios y rutas

# %% [markdown]
# Rutas absolutas vs. relativas

# %% [markdown]
# Una ruta **absoluta** indica la localización de una carpeta o archivo independientemente del directorio actual o raíz.

# %% [markdown]
# Ejemplo de la ruta absoluta de este archivo(en MI computadora):

# %%
direccion_actual = os.getcwd()

# %%
print(direccion_actual)

# %% [markdown]
# ¿Qué pasa si quiero ejecutar acciones de mi script en otra computadora?
#
# Por ejemplo, leer información del archivo: '/Data/COVID_EC/casos_de_coronavirus_en_ecuador__desde_el_inicio_de_la_pandemia.csv'

# %% [markdown]
# **Dirección absoluta:** \'/Users/paul/GoogleDrive/Cursos_master/Analítica_de_datos/Data/COVID_EC/casos_de_coronavirus_en_ecuador__desde_el_inicio_de_la_pandemia.csv'

# %% [markdown]
# Uso de la libería **pandas ó pd**  para leer datos:\
# pd.read_csv(RutadelArchivo)

# %%
data_COVID_EC = pd.read_csv('/Users/paul/Google Drive/Cursos_master/Analítica_de_datos/Data/COVID_EC/casos_de_coronavirus_en_ecuador__desde_el_inicio_de_la_pandemia.csv',sep=';')

# %%
data_COVID_EC.head(n=5)

# %% [markdown]
# ¿Cuál es el error?
# <img src="attachment:interrogation.png" width="200">

# %% [markdown]
# Una ruta **relativa** indica una localización **respecto al directorio actual de cada computadora**.
#
# Contiene solamente información relevante para el proyecto dentro de una misma computadora.

# %% [markdown]
# Dirección relativa = dirección actual [ os.getcwd( ) ] + dirección interna del proyecto

# %% [markdown]
# Intentemos nuevamente leer el archivo con un dirección relativa:

# %%
direccion_actual = os.getcwd()
print('dirección_actual= ',direccion_actual)
direccion_interna_Data = 'Data/COVID_EC'
print('dirección_interna',direccion_interna_Data)

# %% [markdown]
# y para juntar direcciones usando **os.path.join** y **pandas**:

# %%
os.path.join(direccion_actual, direccion_interna_Data)

# %%
data_COVID_EC = pd.read_csv(os.path.join(direccion_actual, direccion_interna_Data, 'casos_de_coronavirus_en_ecuador__desde_el_inicio_de_la_pandemia.csv'),sep=';')

# %%
data_COVID_EC.head(n=5)

# %% [markdown]
# Ejercicio: Leer datos de población por provincia del archivo en 'Data/Population_Provinces'

# %% [markdown]
# ## 2. Creación de carpetas

# %% [markdown]
# Crear carpetas en el directorio actual con la función **os.mkdir**('NombreCarpeta')

# %%
os.mkdir('Figuras')

# %% [markdown]
# Crear carpetas en rutas relativas. \
# Por ejemplo 'Figuras/Population_provinces/'

# %% [markdown]
# Uso de os.path.join

# %%
os.path.join(direccion_actual,'Figuras/Population_provinces')

# %%
os.mkdir(os.path.join(direccion_actual,'Figuras/Population_provinces'))

# %% [markdown]
# Lo mismo pero para la carpeta 'Figuras/COVID_EC'

# %%
os.mkdir(os.path.join(direccion_actual,'Figuras/COVID_EC'))

# %% [markdown]
# ## 3. Exportar archivos en carpetas creadas

# %% [markdown]
# Crear una figura a partir de los datos usando la librería **matplotlib**

# %%
fig = plt.subplots(figsize=(12,8))
plt.bar(data_population_provinces['provincia'],data_population_provinces['población'] )
plt.ylabel('Población')
plt.xlabel('Provincias del Ecuador')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Exportar la figura con el comando **plt.savefig()**

# %%
fig = plt.subplots(figsize=(12,8))
plt.bar(data_population_provinces['provincia'],data_population_provinces['población'] )
plt.ylabel('Población')
plt.xlabel('Provincias del Ecuador')
plt.xticks(rotation = 60)
plt.tight_layout()
plt.savefig(os.path.join(direccion_actual, 'Figuras/Population_provinces','Población_por_provincia.png'), format='png', dpi=300)

# %% [markdown]
# Ejercicio. Generar la figura para COVID con la función **plt.plot(data_COVID_EC['Casos de coronavirus'].cumsum())**
# Exportar la figura a la dirección **'Figuras/COVID_EC'**
